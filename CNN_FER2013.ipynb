# %% [markdown]
# <a href="https://colab.research.google.com/github/NasreddineG/Machine-Learning/blob/main/CNN_FER2013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Détection d'émotions sur des images grâce au CNN***

# %% [markdown]
# L'objectif du projet est de construire à l'aide d'un CNN (Convolution Neural Network ou réseau neuronal convolutif) une reconnaissance des émotions sur des images.
#
# Pour ce faire, il nous faut une base d'apprentissage et d'entraînement. Pour cela, nous allons utiliser pour ça le dataset FER-2013 disponible sur Kaggle (https://www.kaggle.com/msambare/fer2013).
#
# Ce dataset est constitué d'images de visages en niveaux de gris de 48x48 pixels. Les images sont plus ou moins centrés et occupent à peu près le même espace.
#
# Il existe 7 émotions différentes dans ces dataset et chaque visages appartient à l'une des 7 émotions suivantes :
#
# - La colère
#
# - Le dégoût
#
# - La peur
#
# - La joie
#
# - La tristesse
#
# - La surprise
#
# - Neutre
#
# .
#
# .
#
# . **/!\ Le GPU doit être sélectionné comme accélérateur matériel pour la bonne exécution.**

# %% [markdown]
# Pour importer le dataset zippé sur collab, il faut l'importer dans un premier temps sur votre drive et connecter votre colab à votre drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Une fois cette connexion réalisée, on va dézipper le fichier se trouvant sur le drive.
#
#
# Cette commande est à exécuter uniquement lors de la première importation du fichier, par la suite le dataset dézippé est définitivement stocké sur votre Drive.

# %%
# !unzip /content/drive/MyDrive/Data/archive.zip -d /content/drive/MyDrive/Data/dataset

# %% [markdown]
# On réalise les importations nécessaires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import cv2 as cv
import os
import tensorflow as tf
import keras
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # ***Extraction des données***

# %%
#Les noms des classes pour connaitre les 7 émotions
Class_name_train=os.listdir("/content/drive/MyDrive/Data/dataset/train")
print('Training Set =', Class_name_train)
Class_name_test=os.listdir("/content/drive/MyDrive/Data/dataset/test")
print('Test Set =', Class_name_test)
# Out:
# Training Set = ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# Test Set = ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %%
#  Plot 12 images aléatoires pour vérifier l'ensemble des données
plt.figure(figsize=(15,11))
n= np.random.randint(0,7)
path = f"/content/drive/MyDrive/Data/dataset/train/{Class_name_train[n]}"
print(f"                         ********************************{Class_name_train[n]}*************************")
for i in range(1,7):
    plt.subplot(3,3,i)
    plt.tight_layout()
    rand_img = cv.imread(path +'/'+ np.random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xticks([])
    plt.yticks([])
# Out:
#                          ********************************fearful*************************

# %% [markdown]
# # ***CLASSIFICATION DES DONNÉES :***
#
# Analysons les jeux de données que nous avons pour voir les proportions des différentes classes et la répartition entre le dataset train et test.

# %%
plt.figure(figsize=(18,8))
plt.suptitle('Emotion Distribution', fontsize=25)

ax1 = plt.subplot(1,2,1)
ax1.set_title('Training Set')
plt.xlabel('Emotion Class', fontsize=14)
plt.ylabel('Number of Images', fontsize=14)
train_count=[]
for i in Class_name_test:
    train_count.append(len(os.listdir("/content/drive/MyDrive/Data/dataset/train/"+i+"/")))
plt.bar(Class_name_train,train_count)

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('Test Set')
plt.xlabel('Emotion Class', fontsize=14)
plt.ylabel('Number of Images', fontsize=14)
train_count=[]
for i in Class_name_test:
    train_count.append(len(os.listdir("/content/drive/MyDrive/Data/dataset/test/"+i+"/")))
plt.bar(Class_name_test,train_count,color="blue")
plt.show()

# %%
train_path = "/content/drive/MyDrive/Data/dataset/train"
test_path = "/content/drive/MyDrive/Data/dataset/test"

x_train = np.array([ len(os.listdir(train_path+'/'+i+'/')) for i in Class_name_train ])
x_test = np.array([ len(os.listdir(test_path+'/'+i+'/')) for i in Class_name_test ])
label = Class_name_train
  
fig, axes = plt.subplots(1, 2, figsize=(20,10))
axes[0].pie(x_train, labels=label, autopct='%1.1f%%',shadow=True, startangle=90)
axes[1].pie(x_test, labels=label, autopct='%1.1f%%',shadow=True, startangle=90)
axes[0].set_title('Training Set')
axes[1].set_title('Test Set')
plt.show()

for i in Class_name_train:
    print('Emotion : ' + i )
    print('\tTraining : ' + str(len(os.listdir(train_path+'/'+i+'/'))) +'\n\t Testing : ' + str(len(os.listdir(test_path+'/'+i+'/'))))
# Out:
# Emotion : angry
# 	Training : 3995
# 	 Testing : 958
# Emotion : disgusted
# 	Training : 436
# 	 Testing : 111
# Emotion : fearful
# 	Training : 4097
# 	 Testing : 1024
# Emotion : happy
# 	Training : 7215
# 	 Testing : 1774
# Emotion : neutral
# 	Training : 4965
# 	 Testing : 1233
# Emotion : sad
# 	Training : 4830
# 	 Testing : 1247
# Emotion : surprised
# 	Training : 3171
# 	 Testing : 831

# %% [markdown]
# On remarque que les pourcentages pour chaque émotion sont un peu près similaire entre le test et le train.
#
# Ainsi, les données sont cohérentes et peuvent être analysées.

# %% [markdown]
# Maintenant que nous avons une meilleure compréhension de nos données d'image, nous pouvons effectuer un prétraitement des données sur nos images pour nous aider à étendre notre ensemble de données et à le rendre plus équilibré.
#
# Le générateur d'images Keras ImageDataGenerator nous permet ainsi d'effectuer une augmentation d'image très facilement.

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

print("Train:")
train_generator = train_datagen.flow_from_directory(directory = "/content/drive/MyDrive/Data/dataset/train",
                                                    target_size = (48,48),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical")

print("\nTest:")
test_generator = test_datagen.flow_from_directory(directory = "/content/drive/MyDrive/Data/dataset/test",
                                                              target_size = (48,48),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical")
# Out:
# Train:
# Found 28709 images belonging to 7 classes.
#
# Test:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# L'ensemble d'entraînement comprend 28 709 images tandis que l'ensemble de test lui en comprend 7 178.
#
# Ce qui est logique pour permettre de bien entraîner le modèle avant de le tester. Cependant, les proportions pour chaque émotion sont similaires ce qui est le plus important pour avoir un résultat réaliste et optimal.

# %% [markdown]
# # ***Convolution Neural Network : CNN***

# %%
CNN= Sequential()
CNN.add(Conv2D(32,(3,3),padding='same',activation='relu',input_shape=(48,48,1)))
CNN.add(Conv2D(64,(3,3),padding='same',activation='relu'))
CNN.add(BatchNormalization())
CNN.add(MaxPool2D(pool_size=(2, 2)))
CNN.add(Dropout(0.25))

CNN.add(Conv2D(128,(3,3),padding='same',activation='relu'))
CNN.add(Conv2D(256,(3,3),padding='same',activation='relu'))
CNN.add(BatchNormalization())
CNN.add(MaxPool2D(pool_size=(2, 2)))
CNN.add(Dropout(0.25))

CNN.add(Conv2D(256,(3,3),padding='same',activation='relu'))
CNN.add(BatchNormalization())
CNN.add(MaxPool2D(pool_size=(2, 2)))
CNN.add(Dropout(0.25))
     

CNN.add(Flatten()) 

CNN.add(Dense(100,activation = 'relu'))

CNN.add(Dense(50,activation = 'relu'))

CNN.add(Dense(225,activation = 'relu'))

CNN.add(BatchNormalization())
CNN.add(Dropout(0.25))

CNN.add(Dense(7, activation='softmax'))

CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  batch_normalization_1 (Batc  (None, 24, 24, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batch_normalization_2 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 100)               921700
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 225)               11475
#
#  batch_normalization_3 (Batc  (None, 225)              900
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 225)               0
#
#  dense_3 (Dense)             (None, 7)                 1582
#
# =================================================================
# Total params: 1,920,931
# Trainable params: 1,919,329
# Non-trainable params: 1,602
# _________________________________________________________________

# %% [markdown]
# Avant de lancer le CNN, vérifiez que vous êtes en GPU.
#
# Pour être sûr que colab exécute le code en GPU on va lui demander avant l'éxecution du CNN de nous confirmer le tf.device qu'il utilise.

# %%
#Vérification que collab utilise le GPU
with tf.device("/device:GPU:0"):
  device_name = tf.test.gpu_device_name()
  print(device_name)
  if device_name == '/device:GPU:0':
    print("ok")
  else : 
    print("NON")

  CNN.compile(loss='categorical_crossentropy',optimizer = tf.keras.optimizers.Adam(lr=0.0005),metrics=['accuracy'])
  history=CNN.fit_generator(train_generator, steps_per_epoch=28709 // 64, epochs=50, validation_data=test_generator, validation_steps=7178 // 64)
# Out:
# /device:GPU:0
# ok
# Epoch 1/50
# 448/448 [==============================] - 68s 130ms/step - loss: 1.8496 - accuracy: 0.2980 - val_loss: 1.7055 - val_accuracy: 0.3202
# Epoch 2/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.4758 - accuracy: 0.4348 - val_loss: 1.3655 - val_accuracy: 0.4640
# Epoch 3/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.2864 - accuracy: 0.5084 - val_loss: 1.5832 - val_accuracy: 0.4448
# Epoch 4/50
# 448/448 [==============================] - 55s 123ms/step - loss: 1.1797 - accuracy: 0.5546 - val_loss: 1.2226 - val_accuracy: 0.5307
# Epoch 5/50
# 448/448 [==============================] - 56s 126ms/step - loss: 1.0837 - accuracy: 0.5923 - val_loss: 1.1595 - val_accuracy: 0.5518
# Epoch 6/50
# 448/448 [==============================] - 73s 164ms/step - loss: 1.0125 - accuracy: 0.6221 - val_loss: 1.1184 - val_accuracy: 0.5831
# Epoch 7/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9441 - accuracy: 0.6492 - val_loss: 1.1592 - val_accuracy: 0.5820
# Epoch 8/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.8637 - accuracy: 0.6785 - val_loss: 1.1294 - val_accuracy: 0.5887
# Epoch 9/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.7949 - accuracy: 0.7091 - val_loss: 1.1009 - val_accuracy: 0.5949
# Epoch 10/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.7064 - accuracy: 0.7415 - val_loss: 1.1598 - val_accuracy: 0.5971
# Epoch 11/50
# 448/448 [==============================] - 66s 147ms/step - loss: 0.6305 - accuracy: 0.7696 - val_loss: 1.1643 - val_accuracy: 0.6014
# Epoch 12/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.5648 - accuracy: 0.7940 - val_loss: 1.1481 - val_accuracy: 0.6078
# Epoch 13/50
# 448/448 [==============================] - 57s 127ms/step - loss: 0.5013 - accuracy: 0.8179 - val_loss: 1.3606 - val_accuracy: 0.6039
# Epoch 14/50
# 448/448 [==============================] - 61s 135ms/step - loss: 0.4429 - accuracy: 0.8416 - val_loss: 1.2742 - val_accuracy: 0.6063
# Epoch 15/50
# 448/448 [==============================] - 56s 124ms/step - loss: 0.3896 - accuracy: 0.8589 - val_loss: 1.3384 - val_accuracy: 0.6145
# Epoch 16/50
# 448/448 [==============================] - 57s 127ms/step - loss: 0.3438 - accuracy: 0.8770 - val_loss: 1.4153 - val_accuracy: 0.6059
# Epoch 17/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.3067 - accuracy: 0.8905 - val_loss: 1.4867 - val_accuracy: 0.5991
# Epoch 18/50
# 448/448 [==============================] - 56s 124ms/step - loss: 0.2877 - accuracy: 0.8991 - val_loss: 1.4978 - val_accuracy: 0.6048
# Epoch 19/50
# 448/448 [==============================] - 56s 124ms/step - loss: 0.2629 - accuracy: 0.9085 - val_loss: 1.6203 - val_accuracy: 0.6002
# Epoch 20/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.2339 - accuracy: 0.9195 - val_loss: 1.4511 - val_accuracy: 0.6109
# Epoch 21/50
# 448/448 [==============================] - 55s 124ms/step - loss: 0.2240 - accuracy: 0.9235 - val_loss: 1.6416 - val_accuracy: 0.6084
# Epoch 22/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.2056 - accuracy: 0.9293 - val_loss: 1.7059 - val_accuracy: 0.6193
# Epoch 23/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.1986 - accuracy: 0.9309 - val_loss: 1.5863 - val_accuracy: 0.6193
# Epoch 24/50
# 448/448 [==============================] - 57s 126ms/step - loss: 0.1854 - accuracy: 0.9377 - val_loss: 1.6827 - val_accuracy: 0.5942
# Epoch 25/50
# 448/448 [==============================] - 56s 126ms/step - loss: 0.1721 - accuracy: 0.9400 - val_loss: 1.7431 - val_accuracy: 0.6099
# Epoch 26/50
# 448/448 [==============================] - 55s 124ms/step - loss: 0.1795 - accuracy: 0.9387 - val_loss: 1.6377 - val_accuracy: 0.6098
# Epoch 27/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.1575 - accuracy: 0.9466 - val_loss: 1.7007 - val_accuracy: 0.6092
# Epoch 28/50
# 448/448 [==============================] - 56s 126ms/step - loss: 0.1538 - accuracy: 0.9488 - val_loss: 1.6501 - val_accuracy: 0.6164
# Epoch 29/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.1539 - accuracy: 0.9478 - val_loss: 1.7587 - val_accuracy: 0.6145
# Epoch 30/50
# 448/448 [==============================] - 56s 124ms/step - loss: 0.1377 - accuracy: 0.9541 - val_loss: 1.7443 - val_accuracy: 0.6183
# Epoch 31/50
# 448/448 [==============================] - 115s 256ms/step - loss: 0.1355 - accuracy: 0.9542 - val_loss: 1.7878 - val_accuracy: 0.6102
# Epoch 32/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.1278 - accuracy: 0.9562 - val_loss: 1.8209 - val_accuracy: 0.6049
# Epoch 33/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.1288 - accuracy: 0.9563 - val_loss: 1.8171 - val_accuracy: 0.6108
# Epoch 34/50
# 448/448 [==============================] - 56s 124ms/step - loss: 0.1260 - accuracy: 0.9574 - val_loss: 1.9215 - val_accuracy: 0.6127
# Epoch 35/50
# 448/448 [==============================] - 56s 126ms/step - loss: 0.1191 - accuracy: 0.9609 - val_loss: 1.9172 - val_accuracy: 0.6151
# Epoch 36/50
# 448/448 [==============================] - 55s 124ms/step - loss: 0.1150 - accuracy: 0.9614 - val_loss: 1.7858 - val_accuracy: 0.6097
# Epoch 37/50
# 448/448 [==============================] - 56s 126ms/step - loss: 0.1175 - accuracy: 0.9593 - val_loss: 1.7777 - val_accuracy: 0.6074
# Epoch 38/50
# 448/448 [==============================] - 57s 128ms/step - loss: 0.1095 - accuracy: 0.9626 - val_loss: 1.8677 - val_accuracy: 0.6200
# Epoch 39/50
# 448/448 [==============================] - 57s 128ms/step - loss: 0.1027 - accuracy: 0.9657 - val_loss: 1.8248 - val_accuracy: 0.6042
# Epoch 40/50
# 448/448 [==============================] - 57s 127ms/step - loss: 0.1000 - accuracy: 0.9660 - val_loss: 1.9035 - val_accuracy: 0.6057
# Epoch 41/50
# 448/448 [==============================] - 57s 127ms/step - loss: 0.1065 - accuracy: 0.9641 - val_loss: 1.8807 - val_accuracy: 0.6151
# Epoch 42/50
# 448/448 [==============================] - 88s 196ms/step - loss: 0.1012 - accuracy: 0.9653 - val_loss: 1.8190 - val_accuracy: 0.6196
# Epoch 43/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.0911 - accuracy: 0.9691 - val_loss: 1.9853 - val_accuracy: 0.6159
# Epoch 44/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.0877 - accuracy: 0.9709 - val_loss: 1.9117 - val_accuracy: 0.6190
# Epoch 45/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.0959 - accuracy: 0.9681 - val_loss: 1.8535 - val_accuracy: 0.6157
# Epoch 46/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.0847 - accuracy: 0.9715 - val_loss: 1.8930 - val_accuracy: 0.6161
# Epoch 47/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.0868 - accuracy: 0.9705 - val_loss: 1.9062 - val_accuracy: 0.6180
# Epoch 48/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.0920 - accuracy: 0.9693 - val_loss: 1.8848 - val_accuracy: 0.6170
# Epoch 49/50
# 448/448 [==============================] - 56s 126ms/step - loss: 0.0852 - accuracy: 0.9722 - val_loss: 1.9229 - val_accuracy: 0.6105
# Epoch 50/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.0829 - accuracy: 0.9721 - val_loss: 2.0487 - val_accuracy: 0.6070

# %%
CNN.evaluate(test_generator)
# Out:
# 113/113 [==============================] - 11s 96ms/step - loss: 2.0480 - accuracy: 0.6069
# [2.0479800701141357, 0.606854259967804]

# %% [markdown]
# On remarque que la précison de notre modèle après avoir exécuté 50 époques est de 63%.

# %% [markdown]
# # ***Analyse des résultats :***

# %%
plt.figure(figsize=(20,10))
plt.suptitle('Loss & Accuracy Over Time', fontsize=25)

plt.subplot(1, 2, 1)
plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.plot(history.history["loss"], label='Training Loss')
plt.plot(history.history["val_loss"], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Concernant la précision, on peut remarquer que la précision du train et du test est à la première itération assez faible (respectivement 30% et 32%).
#
# Cependant, durant les itérations, on remarque une progression. En effet, après 50 itérations, nous sommes à une précision de 97% pour le train  et une précision de 6.5% pour le dataset test.0

# %% [markdown]
# Concernant les pertes, on peut remarquer que les pertes  diminuent en passant  de 1.85 à 0.08 pour l'entraînement  et de 1.70 à 2.0 pour le test.
#
# Cependant, cela est étrange que les pertes lors du test descendent à 1 en 5 itérations avant de remonter par la suite

# %% [markdown]
# Au vu des ces résultats, et de la différence majeures entre l'entraînement et le test nous pouvons supposer que notre modèle a fait du surapprentissage.
#
# Pour remédier à ça, on peut **agrandir l'échantillon **d'entraînement et éventuellement **augmenter le nombre d'étapes**.

# %% [markdown]
# # ***Analyse des émotions :***

# %%
#Matrice de confusion

y_pred = CNN.predict(test_generator)

y_pred_labels = []
for i in y_pred:
    y_pred_labels.append(np.argmax(i))

y_actual = test_generator.classes[test_generator.index_array]

cm = metrics.confusion_matrix(y_actual, y_pred_labels)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

print("\n","\n",test_generator.class_indices)
# Out:
# 113/113 [==============================] - 10s 93ms/step
#
#  {'angry': 0, 'disgusted': 1, 'fearful': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprised': 6}

# %% [markdown]
# Le modèle ne reconnaît pas sans grande surprise les images de dégoût au vu du pourcentage très faiblement présent dans les datasets. Cependant, le modèle classe en grande majorité les images "dégoûtées" dans les catégorie énervée, triste et neutre ce qui reste cohérent.
#
# L'émotion la mieux reconnu est la joie avec 429 bonnes images, ce qui est cohérent sachant que c'est le plus gros pourcentage dans la répartition des images dans chaque classe. Cependant, les 325 images joyeuses classées comme énervées est surprenantes.
#
# On remarque que les performances ne sont pas aussi bonnes pour les autres classes. L'une des raisons de ce phénomène pourrait être le fait que ces classes contiennent moins de données que les classes heureuses.
#
# En effet, il y a une certaines corrélation entre les classes contenant le plus d'image et celle ayant les meilleurs résultats qui sont les émotions joyeux, neutre, triste.

# %%
#Sauvegarder le modèle
keras_file="CNN"
tf.keras.models.save_model(CNN,keras_file)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
